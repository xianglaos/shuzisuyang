# %%
import pandas as pd
data1 = pd.read_excel('商品销售数据.xlsx', sheet_name='信息表')
data1
# Out:
#     商品大类 商品小类       商品名称    商品编号  商品销售价
# 0   运动上装   背心       瑜伽背心   bx001     48
# 1   运动上装   背心     跑步运动背心   bx002     39
# 2   运动上装   背心     纯色简约背心   bx003     36
# 3   运动上装   背心     轻薄透气背心   bx004     49
# 4   运动上装   背心     修身运动背心   bx005     50
# 5   运动上装   背心     美背裸感背心   bx006     59
# 6   运动上装   短袖   网纱拼接美背短袖   dx001     58
# 7   运动上装   短袖   透气跑步运动短袖   dx002     55
# 8   运动上装   短袖     瑜伽修身短袖   dx003     56
# 9   运动上装   短袖     圆领宽松短袖   dx004     50
# 10  运动上装   长袖    半拉链立领长袖   cx001     69
# 11  运动上装   长袖   修身显瘦瑜伽长袖   cx002     79
# 12  运动上装   长袖   网纱拼接瑜伽长袖   cx003     80
# 13  运动上装   外套     瑜伽运动外套   wt001     66
# 14  运动上装   外套   立领弹力修身外套   wt002     68
# 15  运动上装   外套   速干户外跑步外套   wt003     78
# 16  运动上装   外套   秋冬连帽跑步外套   wt004     88
# 17  运动下装   短裤   跑步宽松速干短裤   dk001     89
# 18  运动下装   短裤   舒适透气瑜伽短裤   dk002     29
# 19  运动下装   短裤    松紧腰跑步短裤   dk003     28
# 20  运动下装   短裤     高腰纯色短裤   dk004     33
# 21  运动下装   长裤   高腰健身休闲长裤  zck001     55
# ...

# %%
data2 = pd.read_excel('商品销售数据.xlsx', sheet_name='销售数据表')
data2
# Out:
#            订单日期          订单编号    商品编号  订单数量
# 0    2022-01-01  HS2022000001   fd003    26
# 1    2022-01-01  HS2022000002   fd004    28
# 2    2022-01-01  HS2022000003   sh001    20
# 3    2022-01-01  HS2022000004   sh003    35
# 4    2022-01-01  HS2022000005   bx002    60
# ...         ...           ...     ...   ...
# 2035 2022-12-31  HS2022002036  zck005    26
# 2036 2022-12-31  HS2022002037   bx003    28
# 2037 2022-12-31  HS2022002038   bx004    20
# 2038 2022-12-31  HS2022002039   bx005    35
# 2039 2022-12-31  HS2022002040   sh001    60
#
# [2040 rows x 4 columns]

# %%
data_all = pd.merge(data1, data2, on='商品编号', how='right')
data_all
# Out:
#       商品大类 商品小类      商品名称    商品编号  商品销售价       订单日期          订单编号  订单数量
# 0     运动配饰   发带    纯色弹力发带   fd003   12.0 2022-01-01  HS2022000001    26
# 1     运动配饰   发带   糖果色弹力发带   fd004   16.0 2022-01-01  HS2022000002    28
# 2     运动配饰   手环    篮球运动手环   sh001    8.0 2022-01-01  HS2022000003    20
# 3     运动配饰   手环   小清新硅胶手环   sh003    6.0 2022-01-01  HS2022000004    35
# 4     运动上装   背心    跑步运动背心   bx002   39.0 2022-01-01  HS2022000005    60
# ...    ...  ...       ...     ...    ...        ...           ...   ...
# 2035  运动下装   长裤  透气冰丝瑜伽长裤  zck005   65.0 2022-12-31  HS2022002036    26
# 2036  运动上装   背心    纯色简约背心   bx003   36.0 2022-12-31  HS2022002037    28
# 2037  运动上装   背心    轻薄透气背心   bx004   49.0 2022-12-31  HS2022002038    20
# 2038  运动上装   背心    修身运动背心   bx005   50.0 2022-12-31  HS2022002039    35
# 2039  运动配饰   手环    篮球运动手环   sh001    8.0 2022-12-31  HS2022002040    60
#
# [2040 rows x 8 columns]

# %%
data_all['销售金额'] = data_all['订单数量'] * data_all['商品销售价']
data_all
# Out:
#       商品大类 商品小类      商品名称    商品编号  商品销售价       订单日期          订单编号  订单数量  \
# 0     运动配饰   发带    纯色弹力发带   fd003   12.0 2022-01-01  HS2022000001    26
# 1     运动配饰   发带   糖果色弹力发带   fd004   16.0 2022-01-01  HS2022000002    28
# 2     运动配饰   手环    篮球运动手环   sh001    8.0 2022-01-01  HS2022000003    20
# 3     运动配饰   手环   小清新硅胶手环   sh003    6.0 2022-01-01  HS2022000004    35
# 4     运动上装   背心    跑步运动背心   bx002   39.0 2022-01-01  HS2022000005    60
# ...    ...  ...       ...     ...    ...        ...           ...   ...
# 2035  运动下装   长裤  透气冰丝瑜伽长裤  zck005   65.0 2022-12-31  HS2022002036    26
# 2036  运动上装   背心    纯色简约背心   bx003   36.0 2022-12-31  HS2022002037    28
# 2037  运动上装   背心    轻薄透气背心   bx004   49.0 2022-12-31  HS2022002038    20
# 2038  运动上装   背心    修身运动背心   bx005   50.0 2022-12-31  HS2022002039    35
# 2039  运动配饰   手环    篮球运动手环   sh001    8.0 2022-12-31  HS2022002040    60
#
#         销售金额
# 0      312.0
# 1      448.0
# 2      160.0
# 3      210.0
# 4     2340.0
# ...      ...
# ...

# %%
data_all['月份'] = data_all['订单日期'].dt.month
data_all
# Out:
#       商品大类 商品小类      商品名称    商品编号  商品销售价       订单日期          订单编号  订单数量  \
# 0     运动配饰   发带    纯色弹力发带   fd003   12.0 2022-01-01  HS2022000001    26
# 1     运动配饰   发带   糖果色弹力发带   fd004   16.0 2022-01-01  HS2022000002    28
# 2     运动配饰   手环    篮球运动手环   sh001    8.0 2022-01-01  HS2022000003    20
# 3     运动配饰   手环   小清新硅胶手环   sh003    6.0 2022-01-01  HS2022000004    35
# 4     运动上装   背心    跑步运动背心   bx002   39.0 2022-01-01  HS2022000005    60
# ...    ...  ...       ...     ...    ...        ...           ...   ...
# 2035  运动下装   长裤  透气冰丝瑜伽长裤  zck005   65.0 2022-12-31  HS2022002036    26
# 2036  运动上装   背心    纯色简约背心   bx003   36.0 2022-12-31  HS2022002037    28
# 2037  运动上装   背心    轻薄透气背心   bx004   49.0 2022-12-31  HS2022002038    20
# 2038  运动上装   背心    修身运动背心   bx005   50.0 2022-12-31  HS2022002039    35
# 2039  运动配饰   手环    篮球运动手环   sh001    8.0 2022-12-31  HS2022002040    60
#
#         销售金额  月份
# 0      312.0   1
# 1      448.0   1
# 2      160.0   1
# 3      210.0   1
# ...

# %%
data_all_1 = data_all.groupby(by='月份', as_index=False)['销售金额'].sum()
data_all_1
# Out:
#     月份      销售金额
# 0    1  344878.0
# 1    2  375111.0
# 2    3  431575.0
# 3    4  408359.0
# 4    5  463358.0
# 5    6  424416.0
# 6    7  490090.0
# 7    8  468356.0
# 8    9  433489.0
# 9   10  485727.0
# 10  11  484643.0
# 11  12  470306.0

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimSun']
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(12, 6))
x = data_all_1['月份']
y = data_all_1['销售金额']
plt.plot(x, y, color='k', linewidth=3, linestyle='solid', marker='s', markersize=8)
plt.title(label='商品每月销售金额折线图', font='KaiTi', fontsize=30, color='k', loc='center')
plt.xlabel('月份', font='KaiTi', fontsize=15, color='k', labelpad=5)
plt.ylabel('销售金额(元)', font='KaiTi', fontsize=15, color='k', labelpad=5)
plt.xticks(x, ['1月', '2月', '3月', '4月', '5月', '6月', '7月', '8月', '9月', '10月', '11月', '12月'])
plt.ylim(300000, 600000)
plt.show()

# %%
data_all_2 = data_all.groupby(by=['月份', '商品大类'], as_index=False)['销售金额'].sum()
list1 = data_all_2[data_all_2['商品大类'] == '运动上装']
list2 = data_all_2[data_all_2['商品大类'] == '运动下装']
list3 = data_all_2[data_all_2['商品大类'] == '运动配饰']

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimSun']
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(12, 6))
x = list1['月份']
y1 = list1['销售金额']
y2 = list2['销售金额']
y3 = list3['销售金额']
plt.bar(x - 0.2, y1, width=0.2, color='k', label='运动上装')
plt.bar(x, y2, width=0.2, color='b', label='运动下装')
plt.bar(x + 0.2, y3, width=0.2, color='r', label='运动配饰')
plt.title(label='运动上装、运动下装和运动配饰月度销售金额对比图', font='KaiTi', fontsize=30, color='k', loc='center')
plt.xlabel('月份', font='KaiTi', fontsize=15, color='k', labelpad=5)
plt.ylabel('销售金额(元)', font='KaiTi', fontsize=15, color='k', labelpad=5)
plt.legend(loc='upper right', fontsize=12)
plt.xticks(x, ['1月', '2月', '3月', '4月', '5月', '6月', '7月', '8月', '9月', '10月', '11月', '12月'])
plt.ylim(0, 400000)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimSun']
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(12, 6))
x = list1['月份']
y1 = list1['销售金额']
y2 = list2['销售金额']
y3 = list3['销售金额']
plt.plot(x, y1, color='k', linewidth=3, linestyle='solid', marker='s', markersize=8, label='运动上装')
plt.plot(x, y2, color='b', linewidth=3, linestyle='solid', marker='o', markersize=8, label='运动下装')
plt.plot(x, y3, color='r', linewidth=3, linestyle='solid', marker='*', markersize=8, label='运动配饰')
plt.title(label='运动上装、运动下装和运动配饰月度销售金额折线图', font='KaiTi', fontsize=30, color='k', loc='center')
plt.xlabel('月份', font='KaiTi', fontsize=15, color='k', labelpad=5)
plt.ylabel('销售金额(元)', font='KaiTi', fontsize=15, color='k', labelpad=5)
plt.legend(loc='upper left', fontsize=12)
plt.xticks(x, ['1月', '2月', '3月', '4月', '5月', '6月', '7月', '8月', '9月', '10月', '11月', '12月'])
plt.ylim(0, 400000)
plt.show()

# %%
data_all_3 = data_all.groupby(by='商品小类', as_index=False)['销售金额'].sum()
data_all_3
# Out:
#   商品小类      销售金额
# 0   发带  185516.0
# 1   外套  982788.0
# 2   手环   82333.0
# 3   短袖  770515.0
# 4   短裤  721880.0
# 5   背心  775496.0
# 6   袜子  254762.0
# 7   长袖  753584.0
# 8   长裤  753434.0

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimSun']
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(12, 6))
x = data_all_3['商品小类']
y = data_all_3['销售金额'] / 10000
plt.bar(x, y, width=0.6, color='k')
plt.title(label='各商品小类年度销售金额对比图', font='KaiTi', fontsize=30, color='k', loc='center')
plt.xlabel('商品小类', font='KaiTi', fontsize=15, color='k', labelpad=5)
plt.ylabel('销售金额(万元)', font='KaiTi', fontsize=15, color='k', labelpad=5)
plt.ylim(0, 120)
for i, j in zip(x, y):
    plt.text(i, j, f'{j:.2f}', ha='center', va='bottom', size=15)
plt.show()
